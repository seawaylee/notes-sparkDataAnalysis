# %%
from pyspark import SparkConf,SparkContext
sc = SparkContext("spark://10.5.110.240:7077","Cluster")

# %%
numsRDD = sc.parallelize([1,2,3,4,5,6,6,7,8,9,10])
sum = numsRDD.reduce(lambda x,y : x+y)
numsRDD.cache()
numsRDD.persist()
numsRDD.collect()
# Out:
# [1, 2, 3, 4, 5, 6, 6, 7, 8, 9, 10]
